# %% [markdown]
# Heike's Holidays in Mallorca - short description.

# %%
persons_name = input("Please type in your name ...")
# Out:
# Please type in your name ...Heike

# %% [markdown]
# Some of the favourite activities of Heike in Mallorca are:
# * Drinking Aperol Spritz on frequent flights directly from Berlin
# * Sailing with girlfriends and a dog
# * Asking for less spicy options in restaurants.

# %%
from IPython.display import HTML

HTML('<img src="https://thumbs.dreamstime.com/b/happy-people-funny-isolated-over-white-background-35582466.jpg" />')
# Out:
# <img src="https://thumbs.dreamstime.com/b/happy-people-funny-isolated-over-white-background-35582466.jpg" />

# %%
from IPython.display import HTML

HTML('<img src="https://dynamic-media-cdn.tripadvisor.com/media/photo-o/15/33/f7/a7/palma-de-mallorca.jpg?w=700&h=500&s=1" />')
# Out:
# <img src="https://dynamic-media-cdn.tripadvisor.com/media/photo-o/15/33/f7/a7/palma-de-mallorca.jpg?w=700&h=500&s=1" />

# %% [markdown]
# Cells run in Python, so I had to import HTML to embed a picture. Other option would be to add photo to a Markdown cell. Below is an example of that.

# %% [markdown]
# ![holiday.jpg](attachment:holiday.jpg)

# %%
# %%HTML
# <iframe width="1000" height="510" src="https://www.youtube.com/embed/QNlGBkHM3vw" /iframe>
# Out:
# <iframe width="1000" height="510" src="https://www.youtube.com/embed/QNlGBkHM3vw" /iframe>

# %% [markdown]
# Here I used the suggested on Google other HTML import (actually the one above used didn't work and I can not figure yet why). Then I went to the video and copied the ready made code for embedding, removed parts of it that didn't fit.
