# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100

# %%
# Load the datasets and investigate 
df1 = pd.read_csv('/Users/justynakurach/Documents/GitHub/IronHackLabs/Week 5/Box Office Performance of Movies with Female Leads/movies.csv')
df2 = pd.read_csv('/Users/justynakurach/Documents/GitHub/IronHackLabs/Week 5/clean_for_modelling.csv')

# %%
df1['imdb'] = df1['imdb'].str[2:]

# %%
df1['imdb'] = df1['imdb'].astype(float)

# %%
df1 = df1.drop(['index', 'code', 'period code'], axis=1)

# %%
df1 = df1.rename(columns={'imdb': 'imdbid'})

# %%
df1
# Out:
#       year     imdbid                                    title  \
# 0     2013  1711425.0                            21 &amp; Over
# 1     2012  1343727.0                                 Dredd 3D
# 2     2013  2024544.0                         12 Years a Slave
# 3     2013  1272878.0                                   2 Guns
# 4     2013   453562.0                                       42
# ...    ...        ...                                      ...
# 1789  1971    67741.0                                    Shaft
# 1790  1971    67800.0                               Straw Dogs
# 1791  1971    67116.0                    The French Connection
# 1792  1971    67992.0  Willy Wonka &amp; the Chocolate Factory
# 1793  1970    65466.0           Beyond the Valley of the Dolls
#
#                  test clean_test binary    budget    domgross     intgross  \
# 0              notalk     notalk   FAIL  13000000  25682380.0   42195766.0
# ...

# %%
df2
# Out:
#                                title     imdbid  bechdel_id  bechdel_score  \
# 0                       Sherlock Jr.    15324.0        2011              0
# 1                Battleship Potemkin    15648.0        1308              0
# 2      Sunrise: A Song of Two Humans    18455.0        1632              2
# 3     All Quiet on the Western Front    20629.0        1316              0
# 4                                  M    22100.0         610              3
# ...                              ...        ...         ...            ...
# 2218              Ghost in the Shell  1219827.0        7551              3
# 2219                     King Arthur  1972591.0        7608              1
# 2220    Murder on the Orient Express  3402236.0        7919              3
# 2221                    Pet Sematary   837563.0        8824              3
# 2222                   Bad Education  8206668.0        9204              3
#
# ...

# %%
merged_df = pd.merge(df1, df2, on='imdbid')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1051 entries, 0 to 1050
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year_x          1051 non-null   int64
#  1   imdbid          1051 non-null   float64
#  2   title_x         1051 non-null   object
#  3   test            1051 non-null   object
#  4   clean_test      1051 non-null   object
#  5   binary          1051 non-null   object
#  6   budget          1051 non-null   int64
#  7   domgross        1051 non-null   float64
#  8   intgross        1051 non-null   float64
#  9   budget_2013$    1051 non-null   int64
#  10  domgross_2013$  1051 non-null   float64
#  11  intgross_2013$  1051 non-null   float64
#  12  decade code     950 non-null    float64
#  13  title_y         1051 non-null   object
#  14  bechdel_id      1051 non-null   int64
#  15  bechdel_score   1051 non-null   int64
#  16  year_y          1051 non-null   int64
# ...

# %%
# Calculate percentage of missing values for each column
nan_percentage = merged_df.isna().mean() * 100

# Print the percentage of missing values for each column
print(nan_percentage)
# Out:
# year_x             0.000000
# imdbid             0.000000
# title_x            0.000000
# test               0.000000
# clean_test         0.000000
# binary             0.000000
# budget             0.000000
# domgross           0.000000
# intgross           0.000000
# budget_2013$       0.000000
# domgross_2013$     0.000000
# intgross_2013$     0.000000
# decade code        9.609895
# title_y            0.000000
# bechdel_id         0.000000
# bechdel_score      0.000000
# year_y             0.000000
# certificate        0.000000
# runtime            0.000000
# genre              0.000000
# imdb_rating        0.000000
# about              0.000000
# director           0.000000
# stars              0.000000
# votes              0.000000
# gross_earn         0.000000
# genre_1            0.000000
# genre_2            5.899144
# genre_3           29.495718
# dtype: float64

# %%
#checked if they match and only one index in year_x is wrong
merged_df['year_match'] = merged_df['year_x'] == merged_df['year_y']

# %%
merged_df = merged_df.drop(['title_x'], axis=1)

# %%
#drop unnecessary collumns
merged_df = merged_df.drop(['year_x', 'year_match'], axis=1)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1051 entries, 0 to 1050
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   imdbid          1051 non-null   float64
#  1   test            1051 non-null   object
#  2   clean_test      1051 non-null   object
#  3   binary          1051 non-null   object
#  4   budget          1051 non-null   int64
#  5   domgross        1051 non-null   float64
#  6   intgross        1051 non-null   float64
#  7   budget_2013$    1051 non-null   int64
#  8   domgross_2013$  1051 non-null   float64
#  9   intgross_2013$  1051 non-null   float64
#  10  decade code     950 non-null    float64
#  11  title_y         1051 non-null   object
#  12  bechdel_id      1051 non-null   int64
#  13  bechdel_score   1051 non-null   int64
#  14  year_y          1051 non-null   int64
#  15  certificate     1051 non-null   object
#  16  runtime         1051 non-null   object
# ...

# %%
merged_df = merged_df.drop(['title_x'], axis=1)

# %%
merged_df.to_csv('smallersetmerged.csv', index=False)
