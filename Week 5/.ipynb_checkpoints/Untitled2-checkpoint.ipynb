# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100

# %%
df = pd.read_csv('/Users/justynakurach/Documents/GitHub/IronHackLabs/Week 5/clean_df_midterm.csv')
# Remove commas from the 'votes' column
df['votes'] = df['votes'].str.replace(',', '')

# Convert the 'votes' column to integer type
df['votes'] = df['votes'].astype(int)

# %%
df = df.drop('poster', axis=1)

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2223 entries, 0 to 2222
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          2223 non-null   object
#  1   imdbid         2223 non-null   float64
#  2   bechdel_id     2223 non-null   int64
#  3   bechdel_score  2223 non-null   int64
#  4   year           2223 non-null   int64
#  5   certificate    2223 non-null   object
#  6   runtime        2223 non-null   object
#  7   genre          2223 non-null   object
#  8   imdb_rating    2223 non-null   float64
#  9   about          2223 non-null   object
#  10  director       2223 non-null   object
#  11  stars          2223 non-null   object
#  12  votes          2223 non-null   int64
#  13  gross_earn     2223 non-null   object
#  14  genre_1        2223 non-null   object
#  15  genre_2        2070 non-null   object
#  16  genre_3        1552 non-null   object
# ...

# %%
df
# Out:
#                                title     imdbid  bechdel_id  bechdel_score  \
# 0                       Sherlock Jr.    15324.0        2011              0
# 1                Battleship Potemkin    15648.0        1308              0
# 2      Sunrise: A Song of Two Humans    18455.0        1632              2
# 3     All Quiet on the Western Front    20629.0        1316              0
# 4                                  M    22100.0         610              3
# ...                              ...        ...         ...            ...
# 2218              Ghost in the Shell  1219827.0        7551              3
# 2219                     King Arthur  1972591.0        7608              1
# 2220    Murder on the Orient Express  3402236.0        7919              3
# 2221                    Pet Sematary   837563.0        8824              3
# 2222                   Bad Education  8206668.0        9204              3
#
# ...

# %%
#clean $ and M signs
df['gross_earn'] = df['gross_earn'].str[:-1]
df['gross_earn'] = df['gross_earn'].str[1:]
#convert to float and to millions
df['gross_earn'] = df['gross_earn'].astype(float) * 1000000

# %%
df
# Out:
#                                title     imdbid  bechdel_id  bechdel_score  \
# 0                       Sherlock Jr.    15324.0        2011              0
# 1                Battleship Potemkin    15648.0        1308              0
# 2      Sunrise: A Song of Two Humans    18455.0        1632              2
# 3     All Quiet on the Western Front    20629.0        1316              0
# 4                                  M    22100.0         610              3
# ...                              ...        ...         ...            ...
# 2218              Ghost in the Shell  1219827.0        7551              3
# 2219                     King Arthur  1972591.0        7608              1
# 2220    Murder on the Orient Express  3402236.0        7919              3
# 2221                    Pet Sematary   837563.0        8824              3
# 2222                   Bad Education  8206668.0        9204              3
#
# ...

# %%
df.to_csv('clean_for_modelling.csv', index=False)
