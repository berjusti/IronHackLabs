# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100

# %%
# Load the datasets and investigate 
df1 = pd.read_csv('/Users/justynakurach/Documents/GitHub/IronHackLabs/Week 5/Movie Bechdel Test Scores/Bechdel.csv')
df2 = pd.read_csv('/Users/justynakurach/Documents/GitHub/IronHackLabs/Week 5/additional datasets/movies.csv')

# %%
df1
# Out:
#                            title      imdbid     id  rating  year
# 0               Passage de Venus   3155794.0   9602       0  1874
# 1              La Rosace Magique  14495706.0   9804       0  1877
# 2     Sallie Gardner at a Gallop   2221420.0   9603       0  1878
# 3              Le singe musicien  12592084.0   9806       0  1878
# 4        Athlete Swinging a Pick   7816420.0   9816       0  1881
# ...                          ...         ...    ...     ...   ...
# 9368                   Love Hard  10752004.0  10152       2  2021
# 9369                     Cruella   3228774.0  10155       3  2021
# 9370             West Side Story   3581652.0  10157       3  2021
# 9371     Every Time a Bell Rings  15943414.0  10158       3  2021
# 9372          Single All The Way  14315756.0  10161       3  2021
#
# [9373 rows x 5 columns]

# %%
df2
# Out:
#                                                  poster  \
# 0     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4     https://m.media-amazon.com/images/S/sash/4Fyxw...
# ...                                                 ...
# 4995  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4996  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4997  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4998  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4999  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                 title certificate         runtime  \
# 0            The Shawshank Redemption          15         142 min
# 1                     The Dark Knight         12A         152 min
# 2                           Inception         12A         148 min
# 3                          Fight Club          18         139 min
# 4                        Pulp Fiction          18         154 min
# ...                               ...         ...             ...
# 4995  Seven Brides for Seven Brothers           U         102 min
# 4996                  Playing It Cool          15          94 min
# 4997             A Moment to Remember     144 min  Drama, Romance
# 4998                        Hairspray          PG          92 min
# 4999             McCabe & Mrs. Miller           X         120 min
#
#                           genre  rating  \
# 0                         Drama     9.3
# 1          Action, Crime, Drama     9.0
# 2     Action, Adventure, Sci-Fi     8.8
# 3                         Drama     8.8
# 4                  Crime, Drama     8.9
# ...                         ...     ...
# 4995     Comedy, Drama, Musical     7.3
# 4996            Comedy, Romance     5.9
# 4997                        NaN     8.1
# 4998      Comedy, Drama, Family     7.0
# 4999             Drama, Western     7.6
#
#                                                   about           director  \
# 0     Two imprisoned men bond over a number of years...     Frank Darabont
# 1     When the menace known as the Joker wreaks havo...  Christopher Nolan
# 2     A thief who steals corporate secrets through t...  Christopher Nolan
# 3     An insomniac office worker and a devil-may-car...      David Fincher
# 4     The lives of two mob hitmen, a boxer, a gangst...  Quentin Tarantino
# ...                                                 ...                ...
# 4995  In 1850 Oregon, when a backwoodsman brings a w...      Stanley Donen
# 4996  Unrequited love motivates a guy to write about...     Justin Reardon
# 4997  A young couple's enduring love is tested when ...        John H. Lee
# 4998  A 'pleasantly plump' teenager teaches 1962 Bal...        John Waters
# 4999  A gambler and a prostitute become business par...      Robert Altman
#
#                                                   stars      votes gross_earn
# 0     ('Tim Robbins',), ('Morgan Freeman',), ('Bob G...  26,26,905    $28.34M
# 1     ('Christian Bale',), ('Heath Ledger',), ('Aaro...  25,98,173   $534.86M
# 2     ('Leonardo DiCaprio',), ('Joseph Gordon-Levitt...  23,04,062   $292.58M
# 3     ('Brad Pitt',), ('Edward Norton',), ('Meat Loa...  20,71,088    $37.03M
# 4     ('John Travolta',), ('Uma Thurman',), ('Samuel...  20,11,013   $107.93M
# ...                                                 ...        ...        ...
# 4995  ('Jane Powell',), ('Howard Keel',), ('Jeff Ric...     25,112     $9.40M
# 4996  ('Chris Evans',), ('Michelle Monaghan',), ('To...     28,515        NaN
# 4997  ('Jung Woo-sung',), ('Son Ye-jin',), ('Jong-ha...     23,957        NaN
# 4998  ('Sonny Bono',), ('Ruth Brown',), ('Divine',),...     21,536     $6.67M
# 4999  ('Warren Beatty',), ('Julie Christie',), ('Ren...     25,097     $8.20M
#
# [5000 rows x 11 columns]

# %%
#only one column in df1 needs to be droppped
df1 = df1.drop('Unnamed: 0', axis=1)

# %%
from fuzzywuzzy import fuzz
# Create an empty list to store the potential matches
potential_matches = []

# Iterate over the movie titles in both datasets
for title1 in df1['title']:
    for title2 in df2['title']:
        score = fuzz.ratio(title1, title2)
        if score > 80:
            potential_matches.append((title1, title2, score))

# Create a DataFrame of potential matches
df_matches = pd.DataFrame(potential_matches, columns=['title1', 'title2', 'score'])

# %%
df_matches.head()

# %%
# merge the two dataframes on 'title'
merged_df = pd.merge(df1, df2, on='title', how='left')

# print the first five rows of the merged dataframe
print(merged_df.head())
# Out:
#                         title      imdbid    id  rating_x  year poster  \
# 0            Passage de Venus   3155794.0  9602         0  1874    NaN
# 1           La Rosace Magique  14495706.0  9804         0  1877    NaN
# 2  Sallie Gardner at a Gallop   2221420.0  9603         0  1878    NaN
# 3           Le singe musicien  12592084.0  9806         0  1878    NaN
# 4     Athlete Swinging a Pick   7816420.0  9816         0  1881    NaN
#
#   certificate runtime genre  rating_y about director stars votes gross_earn
# 0         NaN     NaN   NaN       NaN   NaN      NaN   NaN   NaN        NaN
# 1         NaN     NaN   NaN       NaN   NaN      NaN   NaN   NaN        NaN
# 2         NaN     NaN   NaN       NaN   NaN      NaN   NaN   NaN        NaN
# 3         NaN     NaN   NaN       NaN   NaN      NaN   NaN   NaN        NaN
# 4         NaN     NaN   NaN       NaN   NaN      NaN   NaN   NaN        NaN

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9494 entries, 0 to 9493
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        9494 non-null   object
#  1   imdbid       9494 non-null   float64
#  2   id           9494 non-null   int64
#  3   rating_x     9494 non-null   int64
#  4   year         9494 non-null   int64
#  5   poster       2733 non-null   object
#  6   certificate  2733 non-null   object
#  7   runtime      2733 non-null   object
#  8   genre        2728 non-null   object
#  9   rating_y     2733 non-null   float64
#  10  about        2725 non-null   object
#  11  director     2733 non-null   object
#  12  stars        2733 non-null   object
#  13  votes        2733 non-null   object
#  14  gross_earn   2556 non-null   object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 1.2+ MB

# %%
# Calculate percentage of missing values for each column
nan_percentage = merged_df.isna().mean() * 100

# Print the percentage of missing values for each column
print(nan_percentage)
# Out:
# title           0.000000
# imdbid          0.000000
# id              0.000000
# rating_x        0.000000
# year            0.000000
# poster         71.213398
# certificate    71.213398
# runtime        71.213398
# genre          71.266063
# rating_y       71.213398
# about          71.297662
# director       71.213398
# stars          71.213398
# votes          71.213398
# gross_earn     73.077733
# dtype: float64

# %%
# Drop rows with any missing values
df_matches_dropped = merged_df.dropna()

# Print the shape of the new dataframe
print(df_matches_dropped.shape)
# Out:
# (2545, 15)

# %%
df_matches_dropped
# Out:
#                     title      imdbid     id  rating_x  year  \
# 86             Cinderella       230.0   5914         3  1899
# 87             Cinderella       230.0   5914         3  1899
# 133             Cleopatra      2101.0   2003         2  1912
# 183          Sherlock Jr.     15324.0   2011         0  1924
# 190   Battleship Potemkin     15648.0   1308         0  1925
# ...                   ...         ...    ...       ...   ...
# 9411        Mortal Kombat    293429.0   9682         2  2021
# 9429           Cinderella  10155932.0  10036         3  2021
# 9430           Cinderella  10155932.0  10036         3  2021
# 9464                 Dune   1160419.0  10052         3  2021
# 9491      West Side Story   3581652.0  10157         3  2021
#
#                                                  poster certificate  runtime  \
# 86    https://m.media-amazon.com/images/S/sash/4Fyxw...           U   74 min
# 87    https://m.media-amazon.com/images/S/sash/4Fyxw...           U  105 min
# 133   https://m.media-amazon.com/images/S/sash/4Fyxw...           A  192 min
# 183   https://m.media-amazon.com/images/S/sash/4Fyxw...           U   45 min
# 190   https://m.media-amazon.com/images/S/sash/4Fyxw...    Rejected   75 min
# ...                                                 ...         ...      ...
# 9411  https://m.media-amazon.com/images/S/sash/4Fyxw...          15  101 min
# 9429  https://m.media-amazon.com/images/S/sash/4Fyxw...           U   74 min
# 9430  https://m.media-amazon.com/images/S/sash/4Fyxw...           U  105 min
# 9464  https://m.media-amazon.com/images/S/sash/4Fyxw...          12  137 min
# 9491  https://m.media-amazon.com/images/S/sash/4Fyxw...           A  153 min
#
#                            genre  rating_y  \
# 86    Animation, Family, Fantasy       7.3
# 87      Adventure, Drama, Family       6.9
# 133    Biography, Drama, History       7.0
# 183      Action, Comedy, Romance       8.2
# 190     Drama, History, Thriller       8.0
# ...                          ...       ...
# 9411  Action, Adventure, Fantasy       5.8
# 9429  Animation, Family, Fantasy       7.3
# 9430    Adventure, Drama, Family       6.9
# 9464   Action, Adventure, Sci-Fi       6.3
# 9491       Crime, Drama, Musical       7.6
#
#                                                   about              director  \
# 86    When Cinderella's cruel stepmother prevents he...        Clyde Geronimi
# 87    When her father unexpectedly dies, young Ella ...       Kenneth Branagh
# 133   Queen Cleopatra VII of Egypt experiences both ...  Joseph L. Mankiewicz
# 183   A film projectionist longs to be a detective, ...         Buster Keaton
# 190   In the midst of the Russian Revolution of 1905...     Sergei Eisenstein
# ...                                                 ...                   ...
# 9411  Three unknowing martial artists are summoned t...    Paul W.S. Anderson
# 9429  When Cinderella's cruel stepmother prevents he...        Clyde Geronimi
# 9430  When her father unexpectedly dies, young Ella ...       Kenneth Branagh
# 9464  A Duke's son leads desert warriors against the...           David Lynch
# 9491  Two youngsters from rival New York City gangs ...        Jerome Robbins
#
#                                                   stars     votes gross_earn
# 86    ('Wilfred Jackson',), ('Hamilton Luske',), ('I...  1,59,181    $85.00M
# 87    ('Lily James',), ('Cate Blanchett',), ('Richar...  1,76,150   $201.15M
# 133   ('Elizabeth Taylor',), ('Richard Burton',), ('...    33,223    $57.78M
# 183   ('Buster Keaton',), ('Kathryn McGuire',), ('Jo...    49,517     $0.98M
# 190   ('Aleksandr Antonov',), ('Vladimir Barskiy',),...    57,550     $0.05M
# ...                                                 ...       ...        ...
# 9411  ('Christopher Lambert',), ('Robin Shou',), ('L...  1,17,933    $70.45M
# 9429  ('Wilfred Jackson',), ('Hamilton Luske',), ('I...  1,59,181    $85.00M
# 9430  ('Lily James',), ('Cate Blanchett',), ('Richar...  1,76,150   $201.15M
# 9464  ('Kyle MacLachlan',), ('Virginia Madsen',), ('...  1,61,293    $30.93M
# 9491  ('Robert Wise',), ('Natalie Wood',), ('George ...  1,13,669    $43.66M
#
# [2545 rows x 15 columns]

# %%
title = 'Alice in Wonderland'
matrix_rows = df_matches_dropped[df_matches_dropped['title'] == title]
matrix_rows
# Out:
#                     title     imdbid    id  rating_x  year  \
# 309   Alice in Wonderland    23753.0  3188         3  1933
# 310   Alice in Wonderland    23753.0  3188         3  1933
# 705   Alice in Wonderland    43274.0  1207         3  1951
# 706   Alice in Wonderland    43274.0  1207         3  1951
# 5918  Alice in Wonderland  1014759.0   699         3  2010
# 5919  Alice in Wonderland  1014759.0   699         3  2010
#
#                                                  poster certificate  runtime  \
# 309   https://m.media-amazon.com/images/S/sash/4Fyxw...          PG  108 min
# 310   https://m.media-amazon.com/images/S/sash/4Fyxw...           U   75 min
# 705   https://m.media-amazon.com/images/S/sash/4Fyxw...          PG  108 min
# 706   https://m.media-amazon.com/images/S/sash/4Fyxw...           U   75 min
# 5918  https://m.media-amazon.com/images/S/sash/4Fyxw...          PG  108 min
# 5919  https://m.media-amazon.com/images/S/sash/4Fyxw...           U   75 min
#
#                              genre  rating_y  \
# 309     Adventure, Family, Fantasy       6.4
# 310   Animation, Adventure, Comedy       7.4
# 705     Adventure, Family, Fantasy       6.4
# 706   Animation, Adventure, Comedy       7.4
# 5918    Adventure, Family, Fantasy       6.4
# 5919  Animation, Adventure, Comedy       7.4
#
#                                                   about        director  \
# 309   Nineteen-year-old Alice returns to the magical...      Tim Burton
# 310   Alice stumbles into the world of Wonderland. W...  Clyde Geronimi
# 705   Nineteen-year-old Alice returns to the magical...      Tim Burton
# 706   Alice stumbles into the world of Wonderland. W...  Clyde Geronimi
# 5918  Nineteen-year-old Alice returns to the magical...      Tim Burton
# 5919  Alice stumbles into the world of Wonderland. W...  Clyde Geronimi
#
#                                                   stars     votes gross_earn
# 309   ('Mia Wasikowska',), ('Johnny Depp',), ('Helen...  4,11,432   $334.19M
# 310   ('Wilfred Jackson',), ('Hamilton Luske',), ('J...  1,40,932     $1.07M
# 705   ('Mia Wasikowska',), ('Johnny Depp',), ('Helen...  4,11,432   $334.19M
# 706   ('Wilfred Jackson',), ('Hamilton Luske',), ('J...  1,40,932     $1.07M
# 5918  ('Mia Wasikowska',), ('Johnny Depp',), ('Helen...  4,11,432   $334.19M
# 5919  ('Wilfred Jackson',), ('Hamilton Luske',), ('J...  1,40,932     $1.07M

# %%
# Check for duplicate movie titles in the final dataframe
duplicates = df_matches_dropped.duplicated(subset='title')

# Count the number of duplicates
num_duplicates = sum(duplicates)

# Print the number of duplicates
print("Number of duplicate movie titles: ", num_duplicates)
# Out:
# Number of duplicate movie titles:  211
